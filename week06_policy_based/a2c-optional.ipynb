# %%
import sys
if 'google.colab' in sys.modules:
    import os

    os.system('apt-get install -y xvfb')
    os.system('wget https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/xvfb -O ../xvfb')
    os.system('apt-get install -y python-opengl ffmpeg')
    os.system('pip install pyglet==1.2.4')

    os.system('python -m pip install -U pygame --user')

    print('setup complete')

# XVFB will be launched if you run on a server
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# Out:
# Starting virtual X frame buffer: Xvfb.

# %% [markdown]
# # Implementing Advantage-Actor Critic (A2C)

# %% [markdown]
# In this notebook you will implement Advantage Actor Critic algorithm that trains on a batch of Atari 2600 environments running in parallel.
#
# Firstly, we will use environment wrappers implemented in file `atari_wrappers.py`. These wrappers preprocess observations (resize, grayscale, take max between frames, skip frames and stack them together) and rewards. Some of the wrappers help to reset the environment and pass `done` flag equal to `True` when agent dies.
# File `env_batch.py` includes implementation of `ParallelEnvBatch` class that allows to run multiple environments in parallel. To create an environment we can use `nature_dqn_env` function. Note that if you are using
# PyTorch and not using `tensorboardX` you will need to implement a wrapper that will log **raw** total rewards that the *unwrapped* environment returns and redefine the implemention of `nature_dqn_env` function here.

# %%
#! wget http://www.atarimania.com/roms/Roms.rar
#! mkdir ./content/
#! mkdir ./content/ROM/
#! unzip ./content/Roms.rar ./content/ROM/
! python -m atari_py.import_roms ./content/Rom/
# Out:
# copying jamesbond.bin from ./content/Rom/James Bond 007.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/jamesbond.bin
# copying up_n_down.bin from ./content/Rom/Up 'n Down (1984) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (009-01) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/up_n_down.bin
# copying koolaid.bin from ./content/Rom/Kool-Aid Man (Kool Aid Pitcher Man) (1983) (M Network, Stephen Tatsumi, Jane Terjung - Kool Aid) (MT4648) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/koolaid.bin
# copying phoenix.bin from ./content/Rom/Phoenix.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/phoenix.bin
# copying private_eye.bin from ./content/Rom/Private Eye.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/private_eye.bin
# copying space_invaders.bin from ./content/Rom/Space Invaders.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/space_invaders.bin
# copying freeway.bin from ./content/Rom/Freeway (1981) (Activision, David Crane) (AG-009, AG-009-04) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/freeway.bin
# copying donkey_kong.bin from ./content/Rom/Donkey Kong (1982) (Coleco - Woodside Design Associates - Imaginative Systems Software, Garry Kitchen) (2451) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/donkey_kong.bin
# copying yars_revenge.bin from ./content/Rom/Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw - Sears) (CX2655 - 49-75167) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/yars_revenge.bin
# copying atlantis.bin from ./content/Rom/Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/atlantis.bin
# copying fishing_derby.bin from ./content/Rom/Fishing Derby (1980) (Activision, David Crane) (AG-004) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/fishing_derby.bin
# copying bowling.bin from ./content/Rom/Bowling (1979) (Atari, Larry Kaplan - Sears) (CX2628 - 6-99842, 49-75117) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/bowling.bin
# copying chopper_command.bin from ./content/Rom/Chopper Command.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/chopper_command.bin
# copying hero.bin from ./content/Rom/H.E.R.O..bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/hero.bin
# copying assault.bin from ./content/Rom/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/assault.bin
# copying ms_pacman.bin from ./content/Rom/Ms. Pac-Man.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/ms_pacman.bin
# copying kangaroo.bin from ./content/Rom/Kangaroo.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/kangaroo.bin
# copying galaxian.bin from ./content/Rom/Galaxian.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/galaxian.bin
# copying wizard_of_wor.bin from ./content/Rom/Wizard of Wor.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/wizard_of_wor.bin
# copying gopher.bin from ./content/Rom/Gopher (Gopher Attack) (1982) (U.S. Games Corporation - JWDA, Sylvia Day, Todd Marshall, Robin McDaniel, Henry Will IV) (VC2001) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/gopher.bin
# copying qbert.bin from ./content/Rom/Q-bert (1983) (Parker Brothers - Western Technologies, Dave Hampton, Tom Sloper) (PB5360) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/qbert.bin
# copying name_this_game.bin from ./content/Rom/Name This Game (Guardians of Treasure, Octopussy) (1983) (U.S. Games Corporation - JWDA, Roger Booth, Sylvia Day, Ron Dubren, Todd Marshall, Robin McDaniel, Wes Trager, Henry Will IV) (VC1007) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/name_this_game.bin
# copying adventure.bin from ./content/Rom/Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/adventure.bin
# copying star_gunner.bin from ./content/Rom/Stargunner (1983) (Telesys, Alex Leavens) (1005) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/star_gunner.bin
# copying riverraid.bin from ./content/Rom/River Raid.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/riverraid.bin
# copying demon_attack.bin from ./content/Rom/Demon Attack.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/demon_attack.bin
# copying alien.bin from ./content/Rom/Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/alien.bin
# copying battle_zone.bin from ./content/Rom/Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/battle_zone.bin
# copying solaris.bin from ./content/Rom/Solaris (The Last Starfighter, Star Raiders II, Universe) (1986) (Atari, Douglas Neubauer, Mimi Nyden) (CX26136) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/solaris.bin
# copying sir_lancelot.bin from ./content/Rom/Sir Lancelot (PAL).bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/sir_lancelot.bin
# copying crazy_climber.bin from ./content/Rom/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/crazy_climber.bin
# copying surround.bin from ./content/Rom/Surround (32 in 1) (Bit Corporation) (R320).bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/surround.bin
# copying ice_hockey.bin from ./content/Rom/Ice Hockey - Le Hockey Sur Glace (1981) (Activision, Alan Miller) (AX-012, CAX-012, AX-012-04) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/ice_hockey.bin
# copying road_runner.bin from patched version of ./content/Rom/Road Runner.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/road_runner.bin
# copying enduro.bin from ./content/Rom/Enduro.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/enduro.bin
# copying gravitar.bin from ./content/Rom/Gravitar (1983) (Atari, Dan Hitchens, Mimi Nyden) (CX2685) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/gravitar.bin
# copying seaquest.bin from ./content/Rom/Seaquest.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/seaquest.bin
# copying carnival.bin from ./content/Rom/Carnival.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/carnival.bin
# copying air_raid.bin from ./content/Rom/Air Raid (Men-A-Vision) (PAL) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/air_raid.bin
# copying pooyan.bin from ./content/Rom/Pooyan.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/pooyan.bin
# copying mr_do.bin from ./content/Rom/Mr. Do! (1983) (CBS Electronics - Individeo, Ed English) (4L4478) (PAL).bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/mr_do.bin
# copying berzerk.bin from ./content/Rom/Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/berzerk.bin
# copying boxing.bin from ./content/Rom/Boxing.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/boxing.bin
# copying zaxxon.bin from ./content/Rom/Zaxxon.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/zaxxon.bin
# copying journey_escape.bin from ./content/Rom/Journey Escape.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/journey_escape.bin
# copying pacman.bin from ./content/Rom/Pac-Man (PAL).bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/pacman.bin
# copying video_pinball.bin from ./content/Rom/Video Pinball - Arcade Pinball (1981) (Atari, Bob Smith - Sears) (CX2648 - 49-75161) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/video_pinball.bin
# copying kung_fu_master.bin from ./content/Rom/Kung-Fu Master (1987) (Activision - Imagineering, Dan Kitchen, Garry Kitchen) (AG-039-04) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/kung_fu_master.bin
# copying venture.bin from ./content/Rom/Venture.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/venture.bin
# copying amidar.bin from ./content/Rom/Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/amidar.bin
# copying time_pilot.bin from ./content/Rom/Time Pilot.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/time_pilot.bin
# copying bank_heist.bin from ./content/Rom/Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/bank_heist.bin
# copying trondead.bin from ./content/Rom/TRON - Deadly Discs.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/trondead.bin
# copying tutankham.bin from ./content/Rom/Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (PB5340) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/tutankham.bin
# copying pitfall.bin from ./content/Rom/Pitfall! - Pitfall Harry's Jungle Adventure.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/pitfall.bin
# copying lost_luggage.bin from ./content/Rom/Lost Luggage [no opening scene].bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/lost_luggage.bin
# copying asterix.bin from ./content/Rom/Asterix (AKA Taz) (1984) (Atari, Jerome Domurat, Steve Woita) (CX2696).bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/asterix.bin
# copying kaboom.bin from ./content/Rom/Kaboom!.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/kaboom.bin
# copying breakout.bin from ./content/Rom/Breakout - Breakaway IV.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/breakout.bin
# copying beam_rider.bin from ./content/Rom/Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/beam_rider.bin
# copying defender.bin from ./content/Rom/Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/defender.bin
# copying frostbite.bin from ./content/Rom/Frostbite (Iceman) (1983) (Activision, Steve Cartwright) (AX-031) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/frostbite.bin
# copying frogger.bin from ./content/Rom/Frogger.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/frogger.bin
# copying double_dunk.bin from ./content/Rom/Double Dunk.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/double_dunk.bin
# copying keystone_kapers.bin from ./content/Rom/Keystone Kapers (PAL).bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/keystone_kapers.bin
# copying asteroids.bin from ./content/Rom/Asteroids [no copyright].bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/asteroids.bin
# copying king_kong.bin from ./content/Rom/King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/king_kong.bin
# copying montezuma_revenge.bin from ./content/Rom/Montezuma's Revenge - Featuring Panama Joe.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/montezuma_revenge.bin
# copying robotank.bin from ./content/Rom/Robot Tank.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/robotank.bin
# copying pong.bin from ./content/Rom/Video Olympics - Pong Sports (Paddle) (1977) (Atari, Joe Decuir - Sears) (CX2621 - 99806, 6-99806, 49-75104) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/pong.bin
# copying krull.bin from ./content/Rom/Krull (1983) (Atari, Jerome Domurat, Dave Staugas) (CX2682) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/krull.bin
# copying tennis.bin from ./content/Rom/Tennis.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/tennis.bin
# copying laser_gates.bin from ./content/Rom/Laser Gates (PAL).bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/laser_gates.bin
# copying centipede.bin from ./content/Rom/Centipede (1983) (Atari - GCC) (CX2676) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/centipede.bin
# copying elevator_action.bin from ./content/Rom/Elevator Action (1983) (Atari, Dan Hitchens) (CX26126) (Prototype) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/elevator_action.bin
# copying skiing.bin from ./content/Rom/Skiing - Le Ski (1980) (Activision, Bob Whitehead) (AG-005, CAG-005, AG-005-04) ~.bin to /external1/meshchaninov/envs/lib/python3.9/site-packages/atari_py/atari_roms/skiing.bin

# %%
import numpy as np
from atari_wrappers import nature_dqn_env, NumpySummaries


env = nature_dqn_env("SpaceInvadersNoFrameskip-v4", nenvs=8, summaries='Numpy')
obs = env.reset()
assert obs.shape == (8, 84, 84, 4)
assert obs.dtype == np.uint8

# %%
plt.imshow(obs[1,:,:,2])

# %% [markdown]
# Next, we will need to implement a model that predicts logits and values. It is suggested that you use the same model as in [Nature DQN paper](https://web.stanford.edu/class/psych209/Readings/MnihEtAlHassibis15NatureControlDeepRL.pdf) with a modification that instead of having a single output layer, it will have two output layers taking as input the output of the last hidden layer. **Note** that this model is different from the model you used in homework where you implemented DQN. You can use your favorite deep learning framework here. We suggest that you use orthogonal initialization with parameter $\sqrt{2}$ for kernels and initialize biases with zeros.

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
def init_weights(m):
    if type(m) in (nn.Linear, nn.Conv2d):
        nn.init.orthogonal_(m.weight.data, math.sqrt(2.0))
        if m.bias is not None:
            m.bias.data.fill_(0)

# %%
class Agent(nn.Module):
    def __init__(self, n_actions):
        super().__init__()
        
        self.n_actions = n_actions
        self._build_architecture(n_actions)
        
        
    def _build_architecture(self, n_actions):
        self.feature_extractor = nn.Sequential(
            nn.Conv2d(4, 32, 8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(64 * 7 * 7, 512),
            nn.ReLU()
        ).apply(init_weights)

        self.actions_head = nn.Linear(512, n_actions).apply(init_weights)
        self.v_head = nn.Linear(512, 1).apply(init_weights)
    
    
    def forward(self, state):
        features = self.feature_extractor(state)
        action_logits = self.actions_head(features)
        state_value = self.v_head(features)
        return action_logits, state_value
    
    
    def get_action(self, state):
        action_logits, state_value = self.forward(state)
        probas = nn.functional.softmax(action_logits)
        
        return torch.multinomial(probas, num_samples=1), action_logits, state_value

# %%
test_state = torch.ones((8, 84, 84, 4))
test_n_actions = 4
test_agent = Agent(test_n_actions)

test_logits, test_state_value = test_agent(test_state)

assert test_logits.shape == torch.Size((test_state.shape[0], test_n_actions))
assert test_state_value.shape == torch.Size((test_state.shape[0], 1))
print('Test passed')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [28], in <cell line: 5>()
#       2 test_n_actions = 4
#       3 test_agent = Agent(test_n_actions)
# ----> 5 test_logits, test_state_value = test_agent(test_state)
#       7 assert test_logits.shape == torch.Size((test_state.shape[0], test_n_actions))
#       8 assert test_state_value.shape == torch.Size((test_state.shape[0], 1))
#
# File /external1/meshchaninov/envs/lib/python3.9/site-packages/torch/nn/modules/module.py:1051, in Module._call_impl(self, *input, **kwargs)
#    1047 # If we don't have any hooks, we want to skip the rest of the logic in
#    1048 # this function, and just call forward.
#    1049 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051     return forward_call(*input, **kwargs)
#    1052 # Do not call functions when jit is used
#    1053 full_backward_hooks, non_full_backward_hooks = [], []
#
# Input In [25], in Agent.forward(self, state)
#      26 def forward(self, state):
# ---> 27     features = self.feature_extractor(state)
#      28     action_logits = self.actions_head(features)
#      29     state_value = self.v_head(features)
#
# File /external1/meshchaninov/envs/lib/python3.9/site-packages/torch/nn/modules/module.py:1051, in Module._call_impl(self, *input, **kwargs)
#    1047 # If we don't have any hooks, we want to skip the rest of the logic in
#    1048 # this function, and just call forward.
#    1049 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051     return forward_call(*input, **kwargs)
#    1052 # Do not call functions when jit is used
#    1053 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /external1/meshchaninov/envs/lib/python3.9/site-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File /external1/meshchaninov/envs/lib/python3.9/site-packages/torch/nn/modules/module.py:1051, in Module._call_impl(self, *input, **kwargs)
#    1047 # If we don't have any hooks, we want to skip the rest of the logic in
#    1048 # this function, and just call forward.
#    1049 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051     return forward_call(*input, **kwargs)
#    1052 # Do not call functions when jit is used
#    1053 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /external1/meshchaninov/envs/lib/python3.9/site-packages/torch/nn/modules/conv.py:443, in Conv2d.forward(self, input)
#     442 def forward(self, input: Tensor) -> Tensor:
# --> 443     return self._conv_forward(input, self.weight, self.bias)
#
# File /external1/meshchaninov/envs/lib/python3.9/site-packages/torch/nn/modules/conv.py:439, in Conv2d._conv_forward(self, input, weight, bias)
#     435 if self.padding_mode != 'zeros':
#     436     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     437                     weight, bias, self.stride,
#     438                     _pair(0), self.dilation, self.groups)
# --> 439 return F.conv2d(input, weight, bias, self.stride,
#     440                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [32, 4, 8, 8], expected input[8, 84, 84, 4] to have 4 channels, but got 84 channels instead

# %% [markdown]
# You will also need to define and use a policy that wraps the model. While the model computes logits for all actions, the policy will sample actions and also compute their log probabilities.  `policy.act` should return a dictionary of all the arrays that are needed to interact with an environment and train the model.
#  Note that actions must be an `np.ndarray` while the other
# tensors need to have the type determined by your deep learning framework.

# %%
class Policy:
    def __init__(self, model):
        self.model = model

    def act(self, inputs):
        
        <Implement policy by calling model, sampling actions and computing their log probs>
        # Should return a dict containing keys ['actions', 'logits', 'log_probs', 'values'].

# %% [markdown]
# Next will pass the environment and policy to a runner that collects partial trajectories from the environment.
# The class that does is is already implemented for you.

# %%
from runners import EnvRunner

# %% [markdown]
# This runner interacts with the environment for a given number of steps and returns a dictionary containing
# keys
#
# * 'observations'
# * 'rewards'
# * 'resets'
# * 'actions'
# * all other keys that you defined in `Policy`
#
# under each of these keys there is a python `list` of interactions with the environment. This list has length $T$ that is size of partial trajectory. Partial trajectory for given moment `t` is part of `ComputeValueTargets.__call__` input argument `trajectory` from moment `t` to the end (i.e. it's different at each iteration in the algorithm).

# %% [markdown]
# To train the part of the model that predicts state values you will need to compute the value targets.
# Any callable could be passed to `EnvRunner` to be applied to each partial trajectory after it is collected.
# Thus, we can implement and use `ComputeValueTargets` callable.
# The formula for the value targets is simple:
#
# $$
# \hat v(s_t) = \left( \sum_{t'=0}^{T - 1} \gamma^{t'}r_{t+t'} \right) + \gamma^T \hat{v}(s_{t+T}),
# $$
#
# In implementation, however, do not forget to use
# `trajectory['resets']` flags to check if you need to add the value targets at the next step when
# computing value targets for the current step. You can access `trajectory['state']['latest_observation']`
# to get last observations in partial trajectory &mdash; $s_{t+T}$.

# %%
class ComputeValueTargets:
    def __init__(self, policy, gamma=0.99):
        self.policy = policy

    def __call__(self, trajectory):
        # This method should modify trajectory inplace by adding
        # an item with key 'value_targets' to it.
        <Compute value targets for a given partial trajectory>

# %% [markdown]
# After computing value targets we will transform lists of interactions into tensors
# with the first dimension `batch_size` which is equal to `env_steps * nenvs`, i.e. you essentially need
# to flatten the first two dimensions.

# %%
class MergeTimeBatch:
    """ Merges first two axes typically representing time and env batch. """
    def __call__(self, trajectory):
        # Modify trajectory inplace.
        <TODO: implement>

# %%
model = <Create your model here>
policy = Policy(model)
runner = EnvRunner(
    env, policy, nsteps=5,
    transforms=[
        ComputeValueTargets(),
        MergeTimeBatch(),
    ])

# %% [markdown]
# Now is the time to implement the advantage actor critic algorithm itself. You can look into your lecture,
# [Mnih et al. 2016](https://arxiv.org/abs/1602.01783) paper, and [lecture](https://www.youtube.com/watch?v=Tol_jw5hWnI&list=PLkFD6_40KJIxJMR-j5A1mkxK26gh_qg37&index=20) by Sergey Levine.

# %%
class A2C:
    def __init__(self,
                 policy,
                 optimizer,
                 value_loss_coef=0.25,
                 entropy_coef=0.01,
                 max_grad_norm=0.5):
        self.policy = policy
        self.optimizer = optimizer
        self.value_loss_coef = value_loss_coef
        self.entropy_coef = entropy_coef
        self.max_grad_norm = max_grad_norm

    def policy_loss(self, trajectory):
        # You will need to compute advantages here.
        <TODO: implement>

    def value_loss(self, trajectory):
        <TODO: implement>

    def loss(self, trajectory):
        <TODO: implement>

    def step(self, trajectory):
        <TODO: implement>

# %% [markdown]
# Now you can train your model. With reasonable hyperparameters training on a single GTX1080 for 10 million steps across all batched environments (which translates to about 5 hours of wall clock time)
# it should be possible to achieve *average raw reward over last 100 episodes* (the average is taken over 100 last
# episodes in each environment in the batch) of about 600. You should plot this quantity with respect to
# `runner.step_var` &mdash; the number of interactions with all environments. It is highly
# encouraged to also provide plots of the following quantities (these are useful for debugging as well):
#
# * [Coefficient of Determination](https://en.wikipedia.org/wiki/Coefficient_of_determination) between
# value targets and value predictions
# * Entropy of the policy $\pi$
# * Value loss
# * Policy loss
# * Value targets
# * Value predictions
# * Gradient norm
# * Advantages
# * A2C loss
#
# For optimization we suggest you use RMSProp with learning rate starting from 7e-4 and linearly decayed to 0, smoothing constant (alpha in PyTorch and decay in TensorFlow) equal to 0.99 and epsilon equal to 1e-5.

# %%
a2c = <Create instance of the algorithm>

<Write your training loop>

# %% [markdown]
# ### Target networks?
#
# You may recall a technique called "target networks" we used a few weeks ago when we trained a DQN agent to play Atari Breakout and wonder why we have not suggested using them here. The answer is that this is more historical than practical.
#
# While the "chasing the target" problem is still present in actor-critic value estimation and target networks do show up in follow-up papers, the original A3C/A2C papers do not mention them and do not explain this omission.
#
# The hypothesis why this may not be a big deal (compared to Q-learning) goes like this. An A3C/A2C agent selects actions based on policy, not an epsilon greedy exploration function, for which the argmax can change drastically due to tiny errors in function approximation. Therefore, errors in the value target caused by target chasing will cause less damage.
#
# Also, the actor-critic gradient relies on the advantage function $A(s_t, a_t) = Q(s_t, a_t) - V(s_t)$. Compare this to the $Q$-function $Q(s_t, a_t) = r(s_t, a_t) + \gamma \cdot \mathbb{E}_{s_{t+1} \mid s_t, a_t} V(s_{t+1})$ used in Q-learning and SARSA: we would expect that any bias in $V$-function approximation will be carried over from $V(s_{t+1})$ to $V(s_t)$ by gradient updates. However, in the formula for the advantage function the two approximations ($Q$-function and $V$-function) come with opposite signs, and thus the errors will cancel out.
#
# The last reason may be computational. Authors were concerned to beat existent algorithms in the wall-clock learning time, and any overhead of parameter copying (target network update) counted against this goal.
